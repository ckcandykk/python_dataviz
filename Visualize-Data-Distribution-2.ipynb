# %% [markdown]
# ## Box plot

# %%
import pandas
from matplotlib import pyplot as plt
import matplotlib

# %%
irisdata = pandas.read_csv('C:\\Users\\CANDY\\Documents\\python_viz\\python_dataviz\\iris.data',header=None)  #ไฟล์ที่ไม่มีหัวตาราง
irisdata.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
setosa_np = irisdata.iloc[:50,:-1].to_numpy()
versicolor_np = irisdata.iloc[50:100,:-1].to_numpy()   
virginica_np = irisdata.iloc[100:,:-1].to_numpy()

# %%
matplotlib.rcParams['figure.figsize'] = [12,12]
plt.subplot(1,4,1)
plt.boxplot(setosa_np[:,0])
plt.subplot(1,4,2)
plt.boxplot(setosa_np[:,1])
plt.subplot(1,4,3)
plt.boxplot(setosa_np[:,2])
plt.subplot(1,4,4)
plt.boxplot(setosa_np[:,3])
plt.show()

# %% [markdown]
# ### HW1
# #### use boxplot to compare features between 3 classes

# %%
plt.subplot(1,4,1)
plt.boxplot(setosa_np[:,0])
plt.subplot(1,4,2)
plt.boxplot(setosa_np[:,1])
plt.subplot(1,4,3)
plt.boxplot(setosa_np[:,2])
plt.subplot(1,4,4)
plt.boxplot(setosa_np[:,3])
plt.show()

# %%
plt.boxplot(setosa_np)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x253e7e56ba8>,
#   <matplotlib.lines.Line2D at 0x253e7e56f60>,
#   <matplotlib.lines.Line2D at 0x253e7e70390>,
#   <matplotlib.lines.Line2D at 0x253e7e706d8>,
#   <matplotlib.lines.Line2D at 0x253e7e7cac8>,
#   <matplotlib.lines.Line2D at 0x253e7e7ce10>,
#   <matplotlib.lines.Line2D at 0x253e7b57f98>,
#   <matplotlib.lines.Line2D at 0x253e7b65588>],
#  'caps': [<matplotlib.lines.Line2D at 0x253e7e56ef0>,
#   <matplotlib.lines.Line2D at 0x253e7e64630>,
#   <matplotlib.lines.Line2D at 0x253e7e70a20>,
#   <matplotlib.lines.Line2D at 0x253e7e70d68>,
#   <matplotlib.lines.Line2D at 0x253e7e7cef0>,
#   <matplotlib.lines.Line2D at 0x253e7b574e0>,
#   <matplotlib.lines.Line2D at 0x253e7b658d0>,
#   <matplotlib.lines.Line2D at 0x253e7b65c18>],
#  'boxes': [<matplotlib.lines.Line2D at 0x253e7e567b8>,
#   <matplotlib.lines.Line2D at 0x253e7e64d68>,
#   <matplotlib.lines.Line2D at 0x253e7e7c780>,
#   <matplotlib.lines.Line2D at 0x253e7b57eb8>],
#  'medians': [<matplotlib.lines.Line2D at 0x253e7e64978>,
#   <matplotlib.lines.Line2D at 0x253e7e70e48>,
#   <matplotlib.lines.Line2D at 0x253e7b57828>,
#   <matplotlib.lines.Line2D at 0x253e7b65f60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x253e7e64cc0>,
#   <matplotlib.lines.Line2D at 0x253e7e7c438>,
#   <matplotlib.lines.Line2D at 0x253e7b57b70>,
#   <matplotlib.lines.Line2D at 0x253e7b65ef0>],
#  'means': []}

# %%
import numpy as np

# %%
f1 = setosa_np[:,0],versicolor_np[:,0],virginica_np[:,0]

# %%
f1
# Out:
# (array([5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.6, 5. , 4.4, 4.9, 5.4, 4.8, 4.8,
#         4.3, 5.8, 5.7, 5.4, 5.1, 5.7, 5.1, 5.4, 5.1, 4.6, 5.1, 4.8, 5. ,
#         5. , 5.2, 5.2, 4.7, 4.8, 5.4, 5.2, 5.5, 4.9, 5. , 5.5, 4.9, 4.4,
#         5.1, 5. , 4.5, 4.4, 5. , 5.1, 4.8, 5.1, 4.6, 5.3, 5. ]),
#  array([7. , 6.4, 6.9, 5.5, 6.5, 5.7, 6.3, 4.9, 6.6, 5.2, 5. , 5.9, 6. ,
#         6.1, 5.6, 6.7, 5.6, 5.8, 6.2, 5.6, 5.9, 6.1, 6.3, 6.1, 6.4, 6.6,
#         6.8, 6.7, 6. , 5.7, 5.5, 5.5, 5.8, 6. , 5.4, 6. , 6.7, 6.3, 5.6,
#         5.5, 5.5, 6.1, 5.8, 5. , 5.6, 5.7, 5.7, 6.2, 5.1, 5.7]),
#  array([6.3, 5.8, 7.1, 6.3, 6.5, 7.6, 4.9, 7.3, 6.7, 7.2, 6.5, 6.4, 6.8,
#         5.7, 5.8, 6.4, 6.5, 7.7, 7.7, 6. , 6.9, 5.6, 7.7, 6.3, 6.7, 7.2,
#         6.2, 6.1, 6.4, 7.2, 7.4, 7.9, 6.4, 6.3, 6.1, 7.7, 6.3, 6.4, 6. ,
#         6.9, 6.7, 6.9, 5.8, 6.8, 6.7, 6.7, 6.3, 6.5, 6.2, 5.9]))

# %%
plt.boxplot(f1)
plt.title('Feature 1 comparsion');

# %%
plt.boxplot(f1,labels=['setosa_np','versicolor_np','virginica_np'])
plt.title('Feature 1 comparsion');

# %% [markdown]
# ### Bubble Chart  ขนาดของวงกลมแสดงค่าของData

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=1000*setosa_np[:,2],c = 'y', alpha = 0.2)

# %% [markdown]
# ## Map

# %%
# !pip install folium
import pandas
import xlrd
# Out:
# Requirement already satisfied: folium in c:\users\candy\miniconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: requests in c:\users\candy\miniconda3\lib\site-packages (from folium) (2.22.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\candy\miniconda3\lib\site-packages (from folium) (2.10.3)
# Requirement already satisfied: numpy in c:\users\candy\miniconda3\lib\site-packages (from folium) (1.17.4)
# Requirement already satisfied: branca>=0.3.0 in c:\users\candy\miniconda3\lib\site-packages (from folium) (0.4.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\candy\miniconda3\lib\site-packages (from requests->folium) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\candy\miniconda3\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\candy\miniconda3\lib\site-packages (from requests->folium) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\candy\miniconda3\lib\site-packages (from requests->folium) (2019.11.28)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\candy\miniconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: six in c:\users\candy\miniconda3\lib\site-packages (from branca>=0.3.0->folium) (1.12.0)

# %%
Debt_df = pandas.read_excel('C:\\Users\\CANDY\\Documents\\python_viz\\python_dataviz\\Average-Debt.xls',skiprows=3)
Debt_df
# Out:
#           ภาค และจังหวัด                                         Unnamed: 1  \
# 0                    NaN                                                NaN
# 1                    NaN                                                NaN
# 2        ทั่วราชอาณาจักร                                                NaN
# 3               ตอนพิเศษ                                                NaN
# 4          กรุงเทพมหานคร                                                NaN
# ..                   ...                                                ...
# 84              นราธิวาส                                                NaN
# 85                   NaN                                                NaN
# 86                   NaN                                                NaN
# 87                ที่มา:  การสำรวจภาวะเศรษฐกิจและสังคมของครัวเรือน  สำนั...
# 88               Source:  The Household Socio - Economic Survey, Nationa...
#
#         2541      2543      2545      2547      2549      2550      2552  \
# 0     1998.0    2000.0    2002.0    2004.0    2006.0    2007.0    2009.0
# 1        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2    69674.0   68405.0   82485.0  104571.0  116585.0  116681.0  134699.3
# 3   131740.0  126527.0  157730.0  155622.0  155212.0  151168.0  199608.1
# 4   138247.0  135137.0  162199.0  160776.0  158059.0  155396.0  207665.0
# ..       ...       ...       ...       ...       ...       ...       ...
# 84   25071.0   15087.0   34023.0   39297.0   57235.0   36368.0   26246.4
# 85       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 86       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 87       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 88       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#         2554      2556           2558    Region and province
# 0     2011.0    2013.0    2015.000000                    NaN
# 1        NaN       NaN            NaN                    NaN
# 2   134899.9  163087.0  156770.455510          Whole Kingdom
# 3   202157.2  273795.0  171837.386694        Greater Bangkok
# 4   218741.4  275576.8  164705.600000                Bangkok
# ..       ...       ...            ...                    ...
# 84   40942.5   44974.1   40566.900000             Narathiwat
# 85       NaN       NaN            NaN                    NaN
# 86       NaN       NaN            NaN                    NaN
# 87       NaN       NaN            NaN                    NaN
# 88       NaN       NaN            NaN                    NaN
#
# [89 rows x 13 columns]

# %%
Debt_df[['Region and province',2549]]
# Out:
#       Region and province      2549
# 0                     NaN    2006.0
# 1                     NaN       NaN
# 2           Whole Kingdom  116585.0
# 3         Greater Bangkok  155212.0
# 4                 Bangkok  158059.0
# ..                    ...       ...
# 84             Narathiwat   57235.0
# 85                    NaN       NaN
# 86                    NaN       NaN
# 87                    NaN       NaN
# 88                    NaN       NaN
#
# [89 rows x 2 columns]

# %%
Debt_df_debt = Debt_df[['Region and province',2549]]

# %%
Debt_df_debt.drop([0,1,2,3,8,31,49,70,85,86,87,88],axis=0,inplace=True)
# Out:
# C:\Users\CANDY\Miniconda3\lib\site-packages\pandas\core\frame.py:4117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
Debt_df_debt
# Out:
#                     Region and province      2549
# 4                               Bangkok  158059.0
# 5                          Samut Prakan   95975.0
# 6                            Nonthaburi  179007.0
# 7                          Pathum Thani  193153.0
# 9              Phra Nakhon Si Ayutthaya   53222.0
# ..                                  ...       ...
# 80                                Trang  133375.0
# 81                           Phattalung  117631.0
# 82                              Pattani   82046.0
# 83                                 Yala   55672.0
# 84                           Narathiwat   57235.0
#
# [77 rows x 2 columns]

# %%
Debt_df_debt.head()
# Out:
#                    Region and province      2549
# 4                              Bangkok  158059.0
# 5                         Samut Prakan   95975.0
# 6                           Nonthaburi  179007.0
# 7                         Pathum Thani  193153.0
# 9             Phra Nakhon Si Ayutthaya   53222.0

# %%
import folium
import pandas as pd

# %%
data_to_plot = Debt_df_debt

# %%
data_to_plot
# Out:
#                     Region and province      2549
# 4                               Bangkok  158059.0
# 5                          Samut Prakan   95975.0
# 6                            Nonthaburi  179007.0
# 7                          Pathum Thani  193153.0
# 9              Phra Nakhon Si Ayutthaya   53222.0
# ..                                  ...       ...
# 80                                Trang  133375.0
# 81                           Phattalung  117631.0
# 82                              Pattani   82046.0
# 83                                 Yala   55672.0
# 84                           Narathiwat   57235.0
#
# [77 rows x 2 columns]

# %%
data_to_plot.head()
# Out:
#                    Region and province      2549
# 4                              Bangkok  158059.0
# 5                         Samut Prakan   95975.0
# 6                           Nonthaburi  179007.0
# 7                         Pathum Thani  193153.0
# 9             Phra Nakhon Si Ayutthaya   53222.0

# %%
country_geo = 'thai.json'

# %%
new_col = list()
for d in data_to_plot['Region and province']:
    new_col.append(d.lstrip())
data_to_plot['Region and province']=new_col
# Out:
# C:\Users\CANDY\Miniconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
map =folium.Map(location=[10,100], zoom_start=5)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map.choropleth(geo_data=country_geo,data=data_to_plot,
              columns=['Region and province',2549],
              key_on='feature.properties.name',
              fill_color='YlGnBu',fill_opacity=0.7,line_opacity=0.2,
              legend_name='Average Debt')
# Out:
# C:\Users\CANDY\Miniconda3\lib\site-packages\folium\folium.py:415: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning

# %%
map.save('plot_data_html')

# %%
from IPython.display import HTML
HTML('<iframe src=plot_data.html width=450 height=700></iframe>')
# Out:
# C:\Users\CANDY\Miniconda3\lib\site-packages\IPython\core\display.py:701: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe src=plot_data.html width=450 height=700></iframe>
